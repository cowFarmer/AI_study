# %%
from PIL import Image

image1 = Image.open('paper/0-1.jpg')
image2 = Image.open('test/paper/200.jpg')

image1.show()
image2.show()

img1_size = image1.size

print(img1_size)
print(image2.size)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=56x56 at 0x7F39459287C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=56x56 at 0x7F39477FBCA0>
# (56, 56)
# (56, 56)
