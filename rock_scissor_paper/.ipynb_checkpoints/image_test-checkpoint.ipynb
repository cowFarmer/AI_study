# %%
from PIL import Image

image1 = Image.open('data/paper/10-1.jpg')
image2 = Image.open('data/test/paper/0-1.jpg')

image1.show()
image2.show()

img1_size = image1.size

print(img1_size)
print(image2.size)
print(image1.getchannel)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=56x56 at 0x7F0ED81E6070>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=56x56 at 0x7F0EC8264040>
# (56, 56)
# (56, 56)
# <bound method Image.getchannel of <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=56x56 at 0x7F0ED81E6070>>
