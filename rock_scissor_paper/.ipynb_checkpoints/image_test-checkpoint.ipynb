# %%
from PIL import Image

image1 = Image.open('test.jpg')
# image2 = Image.open('data/test/paper/0-1.jpg')

image1.show()
# image2.show()

img1_size = image1.size

print(img1_size)
print(image2.size)
print(image1.getchannel)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=56x56 at 0x7F15344CE9A0>
# (56, 56)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_79/3688081506.py in <module>
#      10
#      11 print(img1_size)
# ---> 12 print(image2.size)
#      13 print(image1.getchannel)
#
# NameError: name 'image2' is not defined

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

img = cv2.imread('test.jpg')

print(img.shape)

plt.imshow(img, cmap='gray')
print(img.shape)
# Out:
# (56, 56, 3)
# (56, 56, 3)

# %%
from PIL import Image


# img = Image.open('test.jpg')
# imgGary = img.convert('L')
# imgGary.save('test_gray.jpg')
# plt.imshow(imgGary)
img1 = Image.open('test_gray.jpg')
plt.imshow(img1)
np.shape(img1)
# Out:
# (56, 56)

# %%
from skimage import color
from skimage import io

img = io.imread('test.jpg')
imgGray = color.rgb2gray(img)
print(imgGray.shape)
plt.imshow(imgGray)
# Out:
# (56, 56)

# %%
import cv2
import numpy as np

img = cv2.imread('test.jpg')
img_cvt = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imshow('img', img)
