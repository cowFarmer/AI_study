# %% [markdown]
# # 15. 🦄 가랏, 몬스터볼! 전설의 포켓몬 찾아 삼만리

# %% [markdown]
# 포켓몬 데이터셋을 가지고 전설의 포켓몬인지 아닌지를 구별해내보자
# 이러한 과정을 탐색적 데이터 분석(Exploratory Data Analysis, EDA)라고 한다.
# [캐글 포켓몬 데이터셋](https://www.kaggle.com/abcsds/pokemon)

# %% [markdown]
# ### 라이브러리 가져오기

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
print('슝=3')
# Out:
# 슝=3

# %% [markdown]
# ### 데이터셋을 pandas로 불러오기

# %%
import os
csv_path = os.getenv("HOME") +"/aiffel/pokemon_eda/data/Pokemon.csv"
original_data = pd.read_csv(csv_path)
print('슝=3')
# Out:
# 슝=3

# %%
pokemon = original_data.copy()
print(pokemon.shape)
pokemon.head()
# Out:
# (800, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# 전설의 포켓몬 데이터셋
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
print(legendary.shape)
legendary.head()
# Out:
# (65, 13)
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       95      125     85           1       True
# 1      125       90    100           1       True
# 2      125       85     90           1       True
# 3      154       90    130           1       True
# 4      154      100    130           1       True

# %%
# 일반 포켓몬 데이터셋
ordinary = pokemon[pokemon["Legendary"] == False].reset_index(drop=True)
print(ordinary.shape)
ordinary.head()
# Out:
# (735, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### 빈 데이터 확인하기

# %%
pokemon.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# ### 전체 컬럼 이해하기

# %%
print(len(pokemon.columns))
pokemon.columns
# Out:
# 13
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### `#`: ID number

# %%
len(set(pokemon["#"]))
# Out:
# 721

# %%
pokemon[pokemon["#"] == 6]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False

# %% [markdown]
# ### `Name`: 이름

# %%
len(set(pokemon["Name"]))
# Out:
# 800

# %% [markdown]
# ### `Type 1`&`Type 2` 포켓몬 속성

# %%
pokemon.loc[[6, 10]]
# Out:
#     #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 6   6  Charizard   Fire  Flying    534  78      84       78      109       85
# 10  8  Wartortle  Water     NaN    405  59      63       80       65       80
#
#     Speed  Generation  Legendary
# 6     100           1      False
# 10     58           1      False

# %%
len(list(set(pokemon["Type 1"]))), len(list(set(pokemon["Type 2"])))
# Out:
# (18, 19)

# %%
# 차집합을 이용해서 알아보기
set(pokemon["Type 2"]) - set(pokemon["Type 1"])
# Out:
# {nan}

# %%
types = list(set(pokemon["Type 1"]))
print(len(types))
print(types)
# Out:
# 18
# ['Electric', 'Fairy', 'Ghost', 'Bug', 'Dragon', 'Grass', 'Flying', 'Ground', 'Fighting', 'Water', 'Steel', 'Poison', 'Fire', 'Dark', 'Ice', 'Rock', 'Normal', 'Psychic']

# %%
# pandas `isna()` 함수로 데이터 비어있는 NaN값의 개수 확인
pokemon["Type 2"].isna().sum()
# Out:
# 386

# %% [markdown]
# ### Type 1, 2 데이터 분포 plot

# %%
plt.figure(figsize=(10, 7))

plt.subplot(211)
sns.countplot(data=ordinary, x="Type 1", order=types).set_xlabel('')
plt.title("[Ordinary Pokemons]")

plt.subplot(212)
sns.countplot(data=legendary, x="Type 1", order=types).set_xlabel('')
plt.title("[Legendary Pokemons]")

plt.show()

# %%
plt.figure(figsize=(12, 10))  

plt.subplot(211)
sns.countplot(data=ordinary, x="Type 2", order=types).set_xlabel('')
plt.title("[Ordinary Pokemons]")

plt.subplot(212)
sns.countplot(data=legendary, x="Type 2", order=types).set_xlabel('')
plt.title("[Legendary Pokemons]")

plt.show()

# %%
# Type1을 Legendary와 비교하기, 피벗 테이블로 비율 보여주기
pd.pivot_table(pokemon, index="Type 1", values="Legendary").sort_values(by=["Legendary"], ascending=False)
# Out:
#           Legendary
# Type 1
# Flying     0.500000
# Dragon     0.375000
# Psychic    0.245614
# Steel      0.148148
# Ground     0.125000
# Fire       0.096154
# Electric   0.090909
# Rock       0.090909
# Ice        0.083333
# Dark       0.064516
# Ghost      0.062500
# Fairy      0.058824
# Grass      0.042857
# Water      0.035714
# Normal     0.020408
# Poison     0.000000
# Fighting   0.000000
# Bug        0.000000

# %%
# Type2를 Legendary와 비교하기, 피벗 테이블로 비율 보여주기
pd.pivot_table(pokemon, index="Type 2", values="Legendary").sort_values(by=["Legendary"], ascending=False)
# Out:
#           Legendary
# Type 2
# Fire       0.250000
# Dragon     0.222222
# Ice        0.214286
# Electric   0.166667
# Fighting   0.153846
# Psychic    0.151515
# Flying     0.134021
# Fairy      0.086957
# Water      0.071429
# Ghost      0.071429
# Dark       0.050000
# Steel      0.045455
# Ground     0.028571
# Rock       0.000000
# Bug        0.000000
# Poison     0.000000
# Normal     0.000000
# Grass      0.000000

# %% [markdown]
# ### `Total` 모든 스탯의 총합

# %%
stats = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]
stats
# Out:
# ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
print("#0 pokemon: ", pokemon.loc[0, "Name"])
print("total: ", int(pokemon.loc[0, "Total"]))
print("stats: ", list(pokemon.loc[0, stats]))
print("sum of all stats: ", sum(list(pokemon.loc[0, stats])))
# Out:
# #0 pokemon:  Bulbasaur
# total:  318
# stats:  [45, 49, 49, 65, 65, 45]
# sum of all stats:  318

# %%
sum(pokemon['Total'].values == pokemon[stats].values.sum(axis=1))
# 포켓몬별 가로 방향으로 가서 axis=1로 지정해줌
# Out:
# 800

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 6)

sns.scatterplot(data=pokemon, x="Type 1", y="Total", hue="Legendary")
# hue 옵션으로 특성 여부에 따라 색상 다르게 표현
plt.show()

# %% [markdown]
# ### 세부 스탯

# %%
figure, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(10, 10)

sns.scatterplot(data=pokemon, y="Total", x="HP", hue="Legendary", ax=ax1)
sns.scatterplot(data=pokemon, y="Total", x="Attack", hue="Legendary", ax=ax2)
sns.scatterplot(data=pokemon, y="Total", x="Defense", hue="Legendary", ax=ax3)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Atk", hue="Legendary", ax=ax4)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Def", hue="Legendary", ax=ax5)
sns.scatterplot(data=pokemon, y="Total", x="Speed", hue="Legendary", ax=ax6)
plt.show()

# %% [markdown]
# ### `Generation` 포켓몬 세대

# %%
plt.figure(figsize=(12, 10))

plt.subplot(211)
sns.countplot(data=ordinary, x="Generation").set_xlabel('')
plt.title("[All Pkemons]")
plt.subplot(212)
sns.countplot(data=legendary, x="Generation").set_xlabel('')
plt.title("[Legendary Pkemons]")
plt.show()

# %% [markdown]
# ### 전설 포켓몬과 일반 포켓몬 차이 알아보기

# %% [markdown]
# ### Total 값

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

sns.scatterplot(data=legendary, y="Type 1", x="Total")
plt.show()

# %%
print(sorted(list(set(legendary["Total"]))))
# Out:
# [580, 600, 660, 670, 680, 700, 720, 770, 780]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

sns.countplot(data=legendary, x="Total")
plt.show()

# %%
round(65 / 9, 2)
# Out:
# 7.22

# %%
print(sorted(list(set(ordinary["Total"]))))
print(len(sorted(list(set(ordinary["Total"])))))
print(round(735 / 195, 2))
# Out:
# [180, 190, 194, 195, 198, 200, 205, 210, 213, 215, 218, 220, 224, 236, 237, 240, 244, 245, 250, 251, 253, 255, 260, 262, 263, 264, 265, 266, 269, 270, 273, 275, 278, 280, 281, 285, 288, 289, 290, 292, 294, 295, 299, 300, 302, 303, 304, 305, 306, 307, 308, 309, 310, 313, 314, 315, 316, 318, 319, 320, 323, 325, 328, 329, 330, 334, 335, 336, 340, 341, 345, 348, 349, 350, 351, 352, 355, 358, 360, 362, 363, 365, 369, 370, 371, 375, 380, 382, 384, 385, 390, 395, 400, 401, 405, 409, 410, 411, 413, 414, 415, 418, 420, 423, 424, 425, 428, 430, 431, 435, 438, 440, 442, 445, 446, 448, 450, 452, 454, 455, 456, 458, 460, 461, 462, 464, 465, 466, 467, 468, 470, 471, 472, 473, 474, 475, 479, 480, 481, 482, 483, 484, 485, 487, 488, 489, 490, 494, 495, 497, 498, 499, 500, 505, 507, 508, 509, 510, 514, 515, 518, 519, 520, 521, 523, 525, 528, 530, 531, 534, 535, 540, 545, 550, 552, 555, 560, 565, 567, 575, 579, 580, 590, 594, 600, 610, 615, 618, 625, 630, 634, 635, 640, 670, 700]
# 195
# 3.77

# %% [markdown]
# 일반 포켓몬과 전설 포켓몬의 total값의 분포도가 다르다.
# 전설의 포켓몬만 갖고 있는 total값이 있다.
#
# = total값은 전설 포켓몬 예측하는데 중요한 요소이다.

# %% [markdown]
# ### 이름

# %%
n1, n2, n3, n4, n5 = legendary[3:6], legendary[14:24], legendary[25:29], legendary[46:50], legendary[52:57]
names = pd.concat([n1, n2, n3, n4, n5]).reset_index(drop=True)
names
# Out:
#       #                      Name    Type 1    Type 2  Total   HP  Attack  \
# 0   150                    Mewtwo   Psychic       NaN    680  106     110
# 1   150       MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 2   150       MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# 3   380                    Latias    Dragon   Psychic    600   80      80
# 4   380         LatiasMega Latias    Dragon   Psychic    700   80     100
# 5   381                    Latios    Dragon   Psychic    600   80      90
# 6   381         LatiosMega Latios    Dragon   Psychic    700   80     130
# 7   382                    Kyogre     Water       NaN    670  100     100
# 8   382       KyogrePrimal Kyogre     Water       NaN    770  100     150
# 9   383                   Groudon    Ground       NaN    670  100     150
# 10  383     GroudonPrimal Groudon    Ground      Fire    770  100     180
# 11  384                  Rayquaza    Dragon    Flying    680  105     150
# ...

# %%
formes = names[13:23]
formes
# Out:
#       #                      Name    Type 1  Type 2  Total  HP  Attack  \
# 13  386        DeoxysNormal Forme   Psychic     NaN    600  50     150
# 14  386        DeoxysAttack Forme   Psychic     NaN    600  50     180
# 15  386       DeoxysDefense Forme   Psychic     NaN    600  50      70
# 16  386         DeoxysSpeed Forme   Psychic     NaN    600  50      95
# 17  641   TornadusIncarnate Forme    Flying     NaN    580  79     115
# 18  641     TornadusTherian Forme    Flying     NaN    580  79     100
# 19  642  ThundurusIncarnate Forme  Electric  Flying    580  79     115
# 20  642    ThundurusTherian Forme  Electric  Flying    580  79     105
# 21  645   LandorusIncarnate Forme    Ground  Flying    600  89     125
# 22  645     LandorusTherian Forme    Ground  Flying    600  89     145
#
#     Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 13       50      150       50    150           3       True
# 14       20      180       20    150           3       True
# ...

# %%
legendary["name_count"] = legendary["Name"].apply(lambda i: len(i))    
legendary.head()
# Out:
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       95      125     85           1       True           8
# 1      125       90    100           1       True           6
# 2      125       85     90           1       True           7
# 3      154       90    130           1       True           6
# 4      154      100    130           1       True          19

# %%
ordinary["name_count"] = ordinary["Name"].apply(lambda i: len(i))    
ordinary.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %%
plt.figure(figsize=(12, 10))

plt.subplot(211)
sns.countplot(data=legendary, x="name_count").set_xlabel('')
plt.title("Legendary")
plt.subplot(212)
sns.countplot(data=ordinary, x="name_count").set_xlabel('')
plt.title("Ordinary")
plt.show()

# %%
print(round(len(legendary[legendary["name_count"] > 9]) / len(legendary) * 100, 2), "%")
# Out:
# 41.54 %

# %%
print(round(len(ordinary[ordinary["name_count"] > 9]) / len(ordinary) * 100, 2), "%")
# Out:
# 15.65 %

# %% [markdown]
# 전설의 포켓몬에서 이름이 유사한 그룹이 있고,
# 긴 이름을 가졌을 확률이 높다

# %%
pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i))
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %%
pokemon["long_name"] = pokemon["name_count"] >= 10
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True

# %% [markdown]
# 모델을 학습시킬 때 `name_count`가 좋을지 `long_name`이 좋을지
# 아직 모르기 때문에 둘 다 활용할 것이다. 이 점 인지하고 있자

# %% [markdown]
# ### 전처리 토큰 추출

# %% [markdown]
# pandas의 `isalpha()` 함수를 이용해서 알파벳이 아닌 문자 전처리하기
# 근데 띄어쓰기도 False처리가 되기 때문에 먼저 띄어쓰기 작업 후 처리하기

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 795      100      150     50           6       True           7      False
# 796      160      110    110           6       True          19       True
# 797      150      130     70           6       True          19       True
# 798      170      130     80           6       True          18       True
# 799      130       90     70           6       True           9      False
#
#            Name_nospace
# 795             Diancie
# ...

# %%
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True
#
#            Name_nospace  name_isalpha
# 0             Bulbasaur          True
# ...

# %%
print(pokemon[pokemon["name_isalpha"] == False].shape)
pokemon[pokemon["name_isalpha"] == False]
# Out:
# (9, 17)
#        #              Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29          Nidoran♀   Poison     NaN    275   55      47       52
# 37    32          Nidoran♂   Poison     NaN    273   46      57       40
# 90    83        Farfetch'd   Normal  Flying    352   52      65       55
# 131  122          Mr. Mime  Psychic   Fairy    460   40      45       65
# 252  233          Porygon2   Normal     NaN    515   85      80       90
# 270  250             Ho-oh     Fire  Flying    680  106     130       90
# 487  439          Mime Jr.  Psychic   Fairy    310   20      25       45
# 525  474         Porygon-Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde50% Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr. Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="Mime Jr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50% Forme", value="Zygarde Forme")

pokemon.loc[[34, 37, 90, 131, 252, 270, 487, 525, 794]]
# Out:
#        #           Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29      Nidoran X   Poison     NaN    275   55      47       52
# 37    32      Nidoran Y   Poison     NaN    273   46      57       40
# 90    83      Farfetchd   Normal  Flying    352   52      65       55
# 131  122        Mr Mime  Psychic   Fairy    460   40      45       65
# 252  233        Porygon   Normal     NaN    515   85      80       90
# 270  250          Ho Oh     Fire  Flying    680  106     130       90
# 487  439        Mime Jr  Psychic   Fairy    310   20      25       45
# 525  474      Porygon Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon[pokemon["name_isalpha"] == False]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, name_count, long_name, Name_nospace, name_isalpha]
# Index: []

# %% [markdown]
# ### 정규표현식을 이용한 토큰화

# %%
import re

# %%
name = "CharizardMega Charizard X"
name_split = name.split(" ")
print(name_split)

temp = name_split[0]
print(temp)

tokens = re.findall('[A-Z][a-z]*', temp)
print(tokens) # 대문자로 시작해서 소문자로 끝나는 패턴 분리 *는 반복을 나타냄

# 위의 과정을 tokens에 배열로 모아두기
tokens = []
for part_name in name_split:
    a = re.findall('[A-Z][a-z]*', part_name)
    tokens.extend(a)
print(tokens)
# Out:
# ['CharizardMega', 'Charizard', 'X']
# CharizardMega
# ['Charizard', 'Mega']
# ['Charizard', 'Mega', 'Charizard', 'X']

# %%
# 함수로 간단하게 토큰화 하기
def tokenize(name):
    name_split = name.split(" ")
    
    tokens = []
    for part_name in name_split:
        a = re.findall('[A-Z][a-z]*', part_name)
        tokens.extend(a)
        
    return np.array(tokens)

name = "CharizardMega Charizard X"
tokenize(name)
# Out:
# array(['Charizard', 'Mega', 'Charizard', 'X'], dtype='<U9')

# %% [markdown]
# 이제 포켓몬에 대입하기

# %%
all_tokens = list(legendary["Name"].apply(tokenize).values)

token_set = []
for token in all_tokens:
    token_set.extend(token)

print(len(set(token_set)))
print(token_set)
# Out:
# 65
# ...

# %% [markdown]
# `Counter()` 사용하기

# %%
from collections import Counter

# %%
a = [1, 1, 0, 0, 0, 1, 1, 2, 3]
print(Counter(a))
Counter(a).most_common()
# Out:
# Counter({1: 4, 0: 3, 2: 1, 3: 1})
# [(1, 4), (0, 3), (2, 1), (3, 1)]

# %%
most_common = Counter(token_set).most_common(10) 
# most_common()안에 숫자 대입해서 원하는 개수 출력 가능
most_common
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Mewtwo', 5),
#  ('Kyurem', 5),
#  ('Deoxys', 4),
#  ('Hoopa', 4),
#  ('Latias', 3),
#  ('Latios', 3),
#  ('Kyogre', 3),
#  ('Groudon', 3)]

# %%
# str.contains 함수로 특정 구문이 있는지 확인할 수 있음
for token, _ in most_common:
    pokemon[f"{token}"] = pokemon["Name"].str.contains(token)

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  ...  Forme   Mega  Mewtwo  Kyurem  Deoxys  Hoopa  Latias  \
# ...

# %% [markdown]
# ### 원 핫 인코딩
# 데이터를 조회할 때 Type1을 보면 0은 Ice속성 1은 Fire속성 이렇게 나타난다.
# 이 방식을 정수 인코딩이라고 하는데 숫자의 대소 관계가 있다는 단점이 있다.
# 이를 해결하기 위해 Bool로 나타내는 원 핫 인코딩을 사용한다.

# %%
print(types)
# Out:
# ['Electric', 'Fairy', 'Ghost', 'Bug', 'Dragon', 'Grass', 'Flying', 'Ground', 'Fighting', 'Water', 'Steel', 'Poison', 'Fire', 'Dark', 'Ice', 'Rock', 'Normal', 'Psychic']

# %%
for t in types:
    pokemon[t] = (pokemon["Type 1"] == t) | (pokemon["Type 2"] == t)
    
pokemon[[["Type 1", "Type 2"] + types][0]].head()
# Out:
#   Type 1  Type 2  Electric  Fairy  Ghost    Bug  Dragon  Grass  Flying  \
# 0  Grass  Poison     False  False  False  False   False   True   False
# 1  Grass  Poison     False  False  False  False   False   True   False
# 2  Grass  Poison     False  False  False  False   False   True   False
# 3  Grass  Poison     False  False  False  False   False   True   False
# 4   Fire     NaN     False  False  False  False   False  False   False
#
#    Ground  Fighting  Water  Steel  Poison   Fire   Dark    Ice   Rock  Normal  \
# 0   False     False  False  False    True  False  False  False  False   False
# 1   False     False  False  False    True  False  False  False  False   False
# 2   False     False  False  False    True  False  False  False  False   False
# 3   False     False  False  False    True  False  False  False  False   False
# 4   False     False  False  False   False   True  False  False  False   False
#
#    Psychic
# 0    False
# 1    False
# 2    False
# 3    False
# ...

# %% [markdown]
# ### 베이스라인

# %%
# 원본 데이터 불러오기
print(original_data.shape)
original_data.head()
# Out:
# (800, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
print(original_data.columns) # 타겟값인 Legendary 빼고 작업하기
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']
target = 'Legendary'
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
X = original_data[features]
print(X.shape)
X.head()
# Out:
# (800, 8)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1

# %%
y = original_data[target]
print(y.shape)
y.head()
# Out:
# (800,)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Legendary, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 8) (640,)
# (160, 8) (160,)

# %% [markdown]
# ### 모델 학습

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=25)
print(model)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# DecisionTreeClassifier(random_state=25)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[144,   3],
#        [  5,   8]])

# %% [markdown]
# 왼쪽 위부터
# TN: 일반 포켓몬 잘 맞춤, FP: 일반 포켓몬을 전설의 포켓몬으로 맞춤,
# FN: 전설의 포켓몬을 일반 포켓몬으로 맞춤, TP: 전설의 포켓몬을 전설의 포켓몬으로 맞춤

# %%
len(legendary)
# Out:
# 65

# %% [markdown]
# 정확도(accuracy)를 맞춘거, 틀린거로 보기 전에
# 전설의 포켓몬과 일반 포켓몬의 비율을 확인해야하는게 중요하다.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.97       147
#         True       0.73      0.62      0.67        13
#
#     accuracy                           0.95       160
#    macro avg       0.85      0.80      0.82       160
# weighted avg       0.95      0.95      0.95       160

# %% [markdown]
# Recall의 비율이 낮다 이는 TP/(FN+TP)

# %% [markdown]
# ### Feature Enginerring과 비교

# %%
print(len(pokemon.columns))
print(pokemon.columns)
# 지금까지 만든 컬럼들로 비교하기 전 제외해야할 컬럼은 무엇일까?
# Out:
# 45
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'name_count',
#        'long_name', 'Name_nospace', 'name_isalpha', 'Forme', 'Mega', 'Mewtwo',
#        'Kyurem', 'Deoxys', 'Hoopa', 'Latias', 'Latios', 'Kyogre', 'Groudon',
#        'Electric', 'Fairy', 'Ghost', 'Bug', 'Dragon', 'Grass', 'Flying',
#        'Ground', 'Fighting', 'Water', 'Steel', 'Poison', 'Fire', 'Dark', 'Ice',
#        'Rock', 'Normal', 'Psychic'],
#       dtype='object')

# %%
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 
            'name_count', 'long_name', 'Forme', 'Mega', 'Mewtwo', 'Kyurem', 'Deoxys', 'Hoopa', 
            'Latias', 'Latios', 'Kyogre', 'Groudon', 'Poison', 'Water', 'Steel', 'Grass', 
            'Bug', 'Normal', 'Fire', 'Fighting', 'Electric', 'Psychic', 'Ghost', 'Ice', 
            'Rock', 'Dark', 'Flying', 'Ground', 'Dragon', 'Fairy']

print(len(features))
target = "Legendary"
# Out:
# 38

# %%
X = pokemon[features]
print(X.shape)
X.head()
# Out:
# (800, 38)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1
#
#    name_count  long_name  ...  Electric  Psychic  Ghost    Ice   Rock   Dark  \
# 0           9      False  ...     False    False  False  False  False  False
# 1           7      False  ...     False    False  False  False  False  False
# 2           8      False  ...     False    False  False  False  False  False
# 3          21       True  ...     False    False  False  False  False  False
# 4          10       True  ...     False    False  False  False  False  False
#
#    Flying  Ground  Dragon  Fairy
# 0   False   False   False  False
# ...

# %%
y = pokemon[target]
print(y.shape)
y.head()
# Out:
# (800,)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Legendary, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 38) (640,)
# (160, 38) (160,)

# %% [markdown]
# ### 트리 재 학습

# %%
model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[141,   6],
#        [  1,  12]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       147
#         True       0.67      0.92      0.77        13
#
#     accuracy                           0.96       160
#    macro avg       0.83      0.94      0.87       160
# weighted avg       0.97      0.96      0.96       160
