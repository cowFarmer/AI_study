# %% [markdown]
# # 주식 예측에 도전해보자

# %% [markdown]
# ARIMA를 통해 시계열 데이터를 예측하는 스터디를 진행했는데 실제 주식값 예측에 도전해보자. 데이터는 [yahoo finance](https://finance.yahoo.com/?guccounter=1) 사이트에서 원하는 종목을 검색 후 historical data를 들어가면 데이터를 다운받을 수 있다. 처음은 __삼성전자로__ 진행해보자.

# %% [markdown]
# # 1. 시계열 데이터 준비

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/005930.KS.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)

df.head()
# Out:
#                Open     High      Low    Close     Adj Close    Volume
# Date
# 2021-02-17  83900.0  84200.0  83000.0  83200.0  81707.648438  18307735
# 2021-02-18  83200.0  83600.0  82100.0  82100.0  80627.382813  21327683
# 2021-02-19  82300.0  82800.0  81000.0  82600.0  81118.414063  25880879
# 2021-02-22  83800.0  84200.0  82200.0  82200.0  80725.593750  25419886
# 2021-02-23  81200.0  82900.0  81100.0  82000.0  80529.179688  20587314

# %% [markdown]
# Open(시작가), High(최고가), Low(최저가), Close(종가), Adj Close(수정종가), Volume(거래량)이 저장되어있다. 종가만 갖고 분석을 진행해보자.

# %%
ts = df['Close']
ts.head()
# Out:
# Date
# 2021-02-17    83200.0
# 2021-02-18    82100.0
# 2021-02-19    82600.0
# 2021-02-22    82200.0
# 2021-02-23    82000.0
# Name: Close, dtype: float64

# %%
plt.plot(ts)

# %% [markdown]
# # 2. 전처리 수행

# %% [markdown]
# ### 2-1. 결측치 처리

# %%
print(ts[ts.isna()])
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 결측치가 없어서 보간은 패스했다.
# ts = ts.interpolate(method='time')
# ts[ts.isna()]

# %% [markdown]
# ### 2-2. 로그 변환

# %%
ts_log = np.log(ts)
plt.plot(ts_log)

# %% [markdown]
# # 3. 시계열 안정성 분석

# %% [markdown]
# ### 3-1. 정성적 그래프 분석, 정량적 ADF test, 시계열 분해

# %%
# 정성적 그래프 분석
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차 시각화
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
#정량적 Augmented Dicky-Fuller Test
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드 호출
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 28) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.889188
# p-value                          0.337164
# #Lags Used                       0.000000
# Number of Observations Used    247.000000
# Critical Value (1%)             -3.457105
# Critical Value (5%)             -2.873314
# Critical Value (10%)            -2.573044
# dtype: float64

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.852252e+00
# p-value                        3.566701e-07
# #Lags Used                     5.000000e+00
# Number of Observations Used    2.140000e+02
# Critical Value (1%)           -3.461282e+00
# Critical Value (5%)           -2.875143e+00
# Critical Value (10%)          -2.574020e+00
# dtype: float64

# %% [markdown]
# p-value 값이 낮게 나와야 시계열 데이터가 안정성있다고 말할 수 있다.
# `3.566701*10^-7 = 0.0000003566701`으로 진행했다.

# %% [markdown]
# # 4. 학습, 테스트 데이터셋 생성

# %% [markdown]
# 학습 9, 테스트1 비율로 데이터셋을 나누자

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# # 5. 적정 ARIMA 파라미터 찾기

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.535769e+01
# p-value                        3.647987e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.460000e+02
# Critical Value (1%)           -3.457215e+00
# Critical Value (5%)           -2.873362e+00
# Critical Value (10%)          -2.573070e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.293282e+00
# p-value                        4.205271e-13
# #Lags Used                     1.100000e+01
# Number of Observations Used    2.340000e+02
# Critical Value (1%)           -3.458608e+00
# Critical Value (5%)           -2.873972e+00
# Critical Value (10%)          -2.573396e+00
# dtype: float64

# %% [markdown]
# 2차 차분보다 1차 차분의 p-value 값이 안정적이게 나왔다.

# %% [markdown]
# ### ARIMA 모델의 파라미터 p, q, d
# ARIMA 모델에 3가지의 파라미터가 있는데 잘 정해야 올바른 예측을 구할 수 있다.
# - p: AR의 시차
# - d: I 횟수
# - q: MA의 시차
#
# ARIMA의 하이퍼파라미터는 `(p, d, q)` 순서다.
# p와 q는 일반적으로 p + q < 2, P * q = 0인 값을 사용하는데 둘중 하나는 0이라는 뜻이다. 왜냐하면 많은 시계열 데이터가 AR이나 MA중 하나의 경향만 갖기 때문이다. 그렇다면 이들은 어떻게 결정될까? 대표적으로 ACF(Autocorrelation Function), PACF(Partial Autocorrelation Function)가 있다.
#
# - ACF 시차(lag)에 따른 관측치들 사이의 관련성을 측정하는 함수, 주어진 시계열의 현재 값이 과거값과 어떻게 상관되는지 설명한다. ACF의 plot에서 X축은 상관 계수, y축은 시차 수를 나타낸다.
# - PACF 다른 관측치의 영향력을 배제하고 두 시차의 관측치 간 관련성을 측정하는 함수, k 이외의 모든 시차를 갖는 관측치의 영향력을 배제한 가운데 특정 두 관측지,  𝑌𝑡 와  𝑌𝑡−𝑘 가 얼마나 관련이 있는지 나타낸다.

# %% [markdown]
# # 6. ARIMA 모델 훈련과 테스트

# %% [markdown]
# ### 6-1. ARIMA 모델 빌드와 훈련

# %%
# Build Model
model = ARIMA(train_data, order=(2, 1, 0))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  223
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                 667.256
# Date:                Thu, 17 Feb 2022   AIC                          -1328.513
# Time:                        11:49:22   BIC                          -1318.304
# Sample:                             0   HQIC                         -1324.391
#                                 - 223
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0581      0.055      1.047      0.295      -0.051       0.167
# ar.L2         -0.0459      0.077     -0.600      0.548      -0.196       0.104
# sigma2         0.0001   9.47e-06     15.152      0.000       0.000       0.000
# ...

# %% [markdown]
# ### 6-2. 모델 테스트 및 플로팅

# %%
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:390: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %% [markdown]
# ### 6-3. 최종 예측 모델 정확도 측정(MAPE)

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  11898456.59482692
# MAE:  2990.6646938696886
# RMSE:  3449.4139494741594
# MAPE: 4.04%

# %% [markdown]
# # 7. 다른 주식 종목 예측해보기

# %% [markdown]
# 이번에는 __애플__ 그리고 __테슬라__ 로 진행해보자.

# %% [markdown]
# # 7-1. 애플

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/AAPL.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)

df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-02-17  131.250000  132.220001  129.470001  130.839996  130.066940
# 2021-02-18  129.199997  130.000000  127.410004  129.710007  128.943619
# 2021-02-19  130.240005  130.710007  128.800003  129.869995  129.102676
# 2021-02-22  128.009995  129.720001  125.599998  126.000000  125.255547
# 2021-02-23  123.760002  126.709999  118.389999  125.860001  125.116379
#
#                Volume
# Date
# 2021-02-17   97918500
# 2021-02-18   96856700
# 2021-02-19   87668800
# 2021-02-22  103916400
# 2021-02-23  158273000

# %%
ts = df['Close']
ts.head()
# Out:
# Date
# 2021-02-17    130.839996
# 2021-02-18    129.710007
# 2021-02-19    129.869995
# 2021-02-22    126.000000
# 2021-02-23    125.860001
# Name: Close, dtype: float64

# %%
plt.plot(ts)

# %%
# 결측치 체크
print(ts[ts.isna()])
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -0.690251
# p-value                          0.849259
# #Lags Used                       0.000000
# Number of Observations Used    253.000000
# Critical Value (1%)             -3.456464
# Critical Value (5%)             -2.873033
# Critical Value (10%)            -2.572895
# dtype: float64

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.449081
# p-value                          0.000243
# #Lags Used                       6.000000
# Number of Observations Used    217.000000
# Critical Value (1%)             -3.460849
# Critical Value (5%)             -2.874953
# Critical Value (10%)            -2.573919
# dtype: float64

# %% [markdown]
# p-value `0.000243` 확인했다.

# %%
# 데이터셋 분할
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.613159e+01
# p-value                        4.778989e-29
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.520000e+02
# Critical Value (1%)           -3.456569e+00
# Critical Value (5%)           -2.873079e+00
# Critical Value (10%)          -2.572919e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.700936e+00
# p-value                        1.339935e-11
# #Lags Used                     1.300000e+01
# Number of Observations Used    2.380000e+02
# Critical Value (1%)           -3.458128e+00
# Critical Value (5%)           -2.873762e+00
# Critical Value (10%)          -2.573283e+00
# dtype: float64

# %% [markdown]
# 삼성전자의 케이스와 동일하게 1차 미분의 `p-value`값이 제일 안정적이다.

# %% [markdown]
# ### 최종 모델 빌드와 훈련

# %%
# Build Model
model = ARIMA(train_data, order=(2, 1, 0))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  228
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                 628.439
# Date:                Thu, 17 Feb 2022   AIC                          -1250.878
# Time:                        11:49:25   BIC                          -1240.603
# Sample:                             0   HQIC                         -1246.732
#                                 - 228
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0657      0.065     -1.014      0.311      -0.193       0.061
# ar.L2         -0.0330      0.060     -0.550      0.582      -0.150       0.084
# sigma2         0.0002   2.02e-05     11.420      0.000       0.000       0.000
# ...

# %%
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:390: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  33.97919466636117
# MAE:  4.151931552436404
# RMSE:  5.829167579196979
# MAPE: 2.51%

# %% [markdown]
# `MAPE` 2.51%로 삼성전자보다 낮게 나왔다.

# %% [markdown]
# # 7-2. 테슬라

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/TSLA.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)

df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-02-17  779.090027  799.840027  762.010010  798.150024  798.150024
# 2021-02-18  780.900024  794.690002  776.270020  787.380005  787.380005
# 2021-02-19  795.000000  796.789978  777.369995  781.299988  781.299988
# 2021-02-22  762.640015  768.500000  710.200012  714.500000  714.500000
# 2021-02-23  662.130005  713.609985  619.000000  698.840027  698.840027
#
#               Volume
# Date
# 2021-02-17  25996500
# 2021-02-18  17957100
# 2021-02-19  18958300
# 2021-02-22  37269700
# 2021-02-23  66606900

# %%
ts = df['Close']
ts.head()
# Out:
# Date
# 2021-02-17    798.150024
# 2021-02-18    787.380005
# 2021-02-19    781.299988
# 2021-02-22    714.500000
# 2021-02-23    698.840027
# Name: Close, dtype: float64

# %%
plt.plot(ts)

# %%
# 결측치 체크
print(ts[ts.isna()])
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.253137
# p-value                          0.650330
# #Lags Used                       0.000000
# Number of Observations Used    253.000000
# Critical Value (1%)             -3.456464
# Critical Value (5%)             -2.873033
# Critical Value (10%)            -2.572895
# dtype: float64

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.567501e+00
# p-value                        8.089813e-09
# #Lags Used                     7.000000e+00
# Number of Observations Used    2.160000e+02
# Critical Value (1%)           -3.460992e+00
# Critical Value (5%)           -2.875016e+00
# Critical Value (10%)          -2.573952e+00
# dtype: float64

# %% [markdown]
# p-value `8.089813e-09` 엄청 낮게 나와 안정적인것을 확인했다.

# %%
# 데이터셋 분할
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.683248e+01
# p-value                        1.155026e-29
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.520000e+02
# Critical Value (1%)           -3.456569e+00
# Critical Value (5%)           -2.873079e+00
# Critical Value (10%)          -2.572919e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.198159e+00
# p-value                        2.404162e-10
# #Lags Used                     1.600000e+01
# Number of Observations Used    2.350000e+02
# Critical Value (1%)           -3.458487e+00
# Critical Value (5%)           -2.873919e+00
# Critical Value (10%)          -2.573367e+00
# dtype: float64

# %% [markdown]
# 삼성전자, 애플과 동일하게 1차 미분의 `p-value`값이 제일 안정적이다.

# %% [markdown]
# ### 최종 모델 빌드와 훈련

# %%
# Build Model
model = ARIMA(train_data, order=(2, 1, 0))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Close   No. Observations:                  228
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                 439.085
# Date:                Thu, 17 Feb 2022   AIC                           -872.171
# Time:                        11:49:27   BIC                           -861.896
# Sample:                             0   HQIC                          -868.025
#                                 - 228
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0525      0.063     -0.834      0.404      -0.176       0.071
# ar.L2          0.0152      0.061      0.251      0.802      -0.104       0.134
# sigma2         0.0012   6.97e-05     17.554      0.000       0.001       0.001
# ...

# %%
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)
# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:390: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  17397.566520072498
# MAE:  118.00342657593494
# RMSE:  131.89983517833713
# MAPE: 13.00%

# %% [markdown]
# # 총 정리

# %% [markdown]
# - 삼성전자: MAPE: 4.04%, 1차 차분값 = 3.647987e-28
# - 애플: MAPE: 2.51%, 1차 차분값 = 4.778989e-29
# - 테슬라: MAPE: 13.00%, 1차 차분값 = 1.155026e-29
#
# 테슬라는 이번에 제작한 모델이 급락을 제대로 반영을 못해서 그런지 몰라도 다른거와 비교하면 많이 안맞게 나왔다. 그리고 예측 모델의 결과를 시각화 한 과정에서 predicted price를 보면 train의 마지막 가격 그대로 일자로 예측하고 있다. 구축할 때 인지하지 못한 큰 실수를 한거같다. 그래서 결과만 두고 보자면 매우 아쉽고 실패한 프로젝트라고 생각한다.

# %% [markdown]
# # 회고

# %% [markdown]
# 처음에 주식을 예측한다고 했을 때 투자도 직접 많이 해본 입장으로써 많이 설렜다. 유의미한 결과가 나오면 연구한 모델을 투자 참고용으로 활용하면 좋겠다고 생각했다. 하지만 시계열 데이터만 이용해서 주식을 예측하기는 너무 어려웠고, 예측하고 추측하는 방식이 내가 상상한것과는 많이 달랐다.
# - 시계열 데이터를 사용할 때 다른 정보를 활용하면 안된다는 점이 매우 아쉬웠다.
# 스터디하면서 나온 내용인데, 유가의 변동 데이터만 활용하면 시계열 데이터 예측이라 한다. 하지만 위성 사진같은 데이터를 활용하면 시계열 예측이 아니라고 한다. 그렇다면 __처음부터 시계열 데이터로 주식 예측 모델에 사용한게 잘못된거 아닐까?__ 왜냐하면 다양한 섹터에서 사용되는 정보 또한 많이 있고(예를들어 자동차는 철강업과 연관되어있고, 유가는 모든 산업에 영향을 많이 미치지만 특히 화학업종과 관련되어있다. 그리고 최근에 많이 이슈되는 친환경은 정치와 크게 관련있다.), 개인적으로 주식은 사람들의 심리에 가장 크게 좌지우지한다고 생각하기 때문이다. ~~RNN 모델링 방법으로 이미지 판별하는 모델 만든 느낌? -> 혹시나해서 찾아보니 RNN으로 MNIST 분류를 구현했다.. -> 내가 표현하고 싶은건 NLP에 특화된 모델로 CV를 해결하려고 애쓰는 모습 같았다. 처음부터 CV에 특화된 모델을 쓰면 되는데..~~ 그래서 이러한 부분을 활용하지 않고 통계학적인 부분만 많이 활용한게 아쉬웠다.
#
#
# - 통계학적인 부분에 개인적인 이해도가 없어서 진행하기 어려웠다.
# 말 그대로 안정적인 시계열을 이해하는 것 부터 귀무가설과 대립가설, p-value를 이용해 불안정한 시계열을 안정적인 시계열 형태로 바꾸는 방법까지 이해하려고 노력은 했지만 완벽하게 이해하고 학습하기에 어려웠다. 그리고 오늘 진행한 프로젝트와 다른 얘기일 수 있지만, 이전부터 뉴스나 기사를 통해 통계를 어떤 관점으로 어떻게 보냐에 따라 결과물이 많이 달라진다고 생각했고, 이번에 진행하면서 스스로 생각한 가설이 맞다고 확신했다. 왜냐하면 어떤 데이터를 갖고올지부터 시작해서 데이터를 분해하고 나온 데이터로 어떻게 해석하는지에 따라 결과가 크게 달라지는데, 이때 중립적으로 생각하지 않으면 크게 편향되게 결과가 나온다. 이번 익스도 시계열이라는 주제를 두고 분석을 진행했는데, 딥러닝 분야처럼 통계학 분야도 잘못 해석하기 시작하면 안좋은 결과만 뱉는 함수를 만든다고 생각했다.
#
# 다른 익스와 달리 개선점같은 부분을 쓰지 않고 개인적인 의견만 많이 내는거 같아서 많이 찜찜하게 끝냈다. 만약에 개인 프로젝트로 주가 예측하는 모델을 제작해야 한다면, 시계열은 이용하지 않을것이다.
