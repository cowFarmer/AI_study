# %% [markdown]
# # 폐렴 진단기 성능 개선 프로젝트

# %% [markdown]
# [kaggle Chest X-Ray Images(pneumonia)](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia) 데이터셋
# ![](https://d3s0tskafalll9.cloudfront.net/media/original_images/12_e0QcAmT.png)
# 폐렴은 말 그대로 폐에 염증이 생긴 상태이다. x-ray 이미지로 봤을 때(정상, 세균성 폐렴, 바이러스성 폐렴) 정상보다 염증이 있을때 흰색이 많이 있는걸 볼 수 있다. 이런 패턴을 딥러닝을 통해 학습시켜 진단을 내리는 모델을 만들어보자

# %% [markdown]
# # 1. 실험 환경 만들기

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %%
# AUTOTUNE 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미한다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 하이퍼 파라미터 변수
# BATCH_SIZE = 16
BATCH_SIZE = 8
# EPOCHS = 25
EPOCHS = 15

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# train에 쓰일 val이 너무 없어서 데이터를 모은 후 8대2로 나누자.

# %%
# filenames에 데이터 모으기
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나누기
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# ### 1-1. 이미지 수 파악하기
# train 데이터 안에 있는 정상 이미지와 폐렴 이미지 수를 파악해보자.

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %% [markdown]
# 파일 경로에 NORMAL이 있으면 정상 PNEUMONIA가 있으면 폐렴 이미지이므로 이를 이용해서 수를 파악할 수 있는걸 확인했다.

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %% [markdown]
# 결과를 보니 폐렴 이미지가 3배 더 많이 있어 imbalance하다. 이번에 사용하는 CNN 모델은 balance가 좋을수록 training을 잘 하므로 차후에 조정하자. test 데이터셋은 평가하기 위해 있고 학습과 관련 없으므로 문제 없다.

# %% [markdown]
# ### 1-2. tf.data로 인스턴스 만들기

# %%
# 데이터셋 만들기
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# ### 1-3. 전처리하기
# - 이미지 경로에 NORMAL, PNEUMONIA로 나눠져 있기 때문에 이를 이용해서 라벨 데이터 만들기
# - 데이터의 사이즈가 제각각일 가능성이 높아 이미지 형식 변환하기

# %%
# 파일 경로의 끝에서 두번째 부분인 NORMAL, PNEUMONIA를 보면 양성, 음성을 확인할 수 있다.
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지 형식 변환하는 함수
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어오는 함수
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# 여기서 사용한 num_parallel_calls 인자는 병렬 데이터셋을 불러오고, 파일 여는데 시간을 단축하는 장점이 있다.

# %%
for image, label in train_ds.take(1): # train_ds에서 take()써서 데이터 하나 가져오기
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %% [markdown]
# 테스트 데이터셋에 동일하게 적용하기

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH) # TEST_PATH에 있는 데이터 리스트 불러오기
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy() # 개수 카운트
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# # 2. 데이터 준비하기

# %% [markdown]
# 의료 영상인 경우 육안으로 구분하기 어려운 미묘한 차이에 더해진 노이즈같은 부수효과가 방해를 줄 수 있기 때문에 모델 학습 augmentation으로 이미지 좌우 반전을 고려했다.

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우 반전
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수 추가
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 3. 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여준다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 4. CNN 모델링

# %% [markdown]
# 이미지 처리에 특화된 CNN 딥러닝 모델을 통해 모델링을 하고 결과를 만들어보자.

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Dropout(0.1),
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(32),
        conv_block(64),
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # 5. 데이터 imbalance 처리

# %% [markdown]
# Normal과 Pneumonia 데이터 중에서 한쪽만 많은 imabalance 현상이 있었다. 그래서 해결하는 방법으로 `Weight balancing` 이라는 테크닉이 사용된다.
# 이 테크닉은 training set의 각 데이터에서 loss를 계산할 때 특정 클래스의 데이터에 더 큰 loss 값을 갖도록 가중치를 부여하는 방법이다.
# - [딥러닝에서 클래스 불균형을 다루는 방법](https://3months.tistory.com/414)

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# weight_for_0 변수는 normal 이미지에 사용한 weight를 weight_for_1 변수는 pneumonia 이미지에 사용할 weight를 세팅할 때 사용한다. 이들은 전체 데이터 건수에 반비례 하도록 설정했다.

# %% [markdown]
# # 6. 모델 훈련

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

with tf.device('/GPU:0'): # 이미지 훈련을 하기 위해 GPU를 사용했다.
    model = build_model() # 위에 선언한 build_model()에 모델을 선언했다.

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
#         optimizer='adam',
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=METRICS,
    )

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 90, 90, 16)        0
# _________________________________________________________________
# sequential (Sequential)      (None, 45, 45, 32)        2160
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 22, 22, 64)        7392
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 11, 11, 128)       27072
# ...

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/15
# 523/523 [==============================] - 66s 100ms/step - loss: 0.5907 - accuracy: 0.6876 - precision: 0.8885 - recall: 0.6632 - val_loss: 1.3036 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 2/15
# 523/523 [==============================] - 51s 98ms/step - loss: 0.3755 - accuracy: 0.8270 - precision: 0.9465 - recall: 0.8133 - val_loss: 0.1409 - val_accuracy: 0.9567 - val_precision: 0.9713 - val_recall: 0.9700
# Epoch 3/15
# 523/523 [==============================] - 51s 98ms/step - loss: 0.3185 - accuracy: 0.8544 - precision: 0.9576 - recall: 0.8416 - val_loss: 0.6403 - val_accuracy: 0.7471 - val_precision: 0.7442 - val_recall: 1.0000
# Epoch 4/15
# 523/523 [==============================] - 52s 99ms/step - loss: 0.2961 - accuracy: 0.8774 - precision: 0.9659 - recall: 0.8656 - val_loss: 0.1718 - val_accuracy: 0.9394 - val_precision: 0.9444 - val_recall: 0.9752
# Epoch 5/15
# ...

# %% [markdown]
# # 7. 결과 확인, 시각화

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 78/78 [==============================] - 4s 53ms/step - loss: 0.4782 - accuracy: 0.8606 - precision: 0.8565 - recall: 0.9333
# Loss: 0.47817185521125793,
# Accuracy: 0.8605769276618958,
# Precision: 0.8564705848693848,
# Recall: 0.9333333373069763

# %% [markdown]
# # 회고

# %% [markdown]
# 첫번째 시도
# - `tf.image.random_flip_left_right(image)` 과정만 새로 추가하여 이미지 데이터를 좌우 반전을 준 것으로 모델을 학습시켰다.
#
# 결과
# 모델 훈련 과정에서 25에포크 기준 val_loss: 0.0919이 나왔지만 test를 돌려보니 Loss: 1.59가 나왔다. 오버피팅으로 판단된다. 그리고 결과 그래프가 너무 일정하지 않다. 이는 일반화가 제대로 되어 있지 않다고 판단했다.

# %% [markdown]
# 두번째 시도
# 오버피팅을 막기 위한 여러가지 시도를 진행했다.
# - BATCH_SIZE를 16에서 8로 낮췄다. 낮게 하면 noise가 많아지고 regularization 효과가 있다.
# - epoch를 25에서 15로 낮췄다.
# - 모델 학습 과정에 tf.keras.layers.Dropout(0.2)을 추가로 많이 넣었다.
# - optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) 아담의 러닝레이트를 0.001로 추가했다.
# - early stopping도 넣고 싶었지만 monitor의 대상이 너무 애매했다. 그 전처럼 val_loss를 보기엔 결과물이 그래프로 확인하면 너무 들쑥날쑥이였다. 그래서 epoch를 낮춰서 진행했다.
#
# 결과
# __목표 accuracy 85%를 넘었다.__ 한 가지 찜찜한 점이 있다면 매번 검사할때마다 결과가 천차만별이다.

# %% [markdown]
# X-RAY 사진을 갖고 폐렴 진단기를 만들어 보았다. 이미지만 봤을땐 사람을 구성하는 요소들이 다 제각각인데 모델이 학습할 때 폐 외에 다른 요소들도 확인하지 않았을까? 어떻게 이미지를 보고 폐렴을 진단할 수 있을까? 하며 의구심이 들었다. 그래서 이번에 캐글 스터디하면서 본 이미지 히트맵을 사용해서 비교하면 확인하면 좋을거 같다.

# %% [markdown]
# ### 캐글에서 관련 주제와 히트맵까지 다룬 노트북이 있어서 가져왔다.
# [X-Ray Pneumonia Detection (~97% Test Accuracy)](https://www.kaggle.com/tavetisyan/x-ray-pneumonia-detection-97-test-accuracy) 내 노트북에도 적용해보려 했지만 어려웠다. 그리고 model.summary()를 보면 Non-trainable params에 숫자가 있음을 확인했다. 이를 찾아보니 역전파로 훈련하는 동안 업데이트 되지 않는 가중치의 수를 의미한다고 한다. 어떤 의미인지 정확히 와닿지 않아서 어렵다.
#
# ~~배울수록 새로운게 많이 나오고 깊게 파고들수록 어렵지만 가끔 알고 있는게 나오면 재미있다.~~
